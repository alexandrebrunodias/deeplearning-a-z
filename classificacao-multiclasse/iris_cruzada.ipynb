# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils

np.random.seed(42)
df = pd.read_csv('iris.csv')
X = df.iloc[:, 0:4].values
y = df.iloc[:, 4].values

labelencoder = LabelEncoder()
y = labelencoder.fit_transform(y)

y_dummy = np_utils.to_categorical(y)

# %%
def criar_rede():
    model = Sequential()
    
    model.add(Dense(units=15, activation='relu', input_dim=4))
    model.add(Dense(units=3, activation='softmax'))
    
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])
    
    return model

# %%
model = KerasClassifier(build_fn=criar_rede, epochs=300, batch_size=10)
result = cross_val_score(estimator=model, X=X, y=y, cv=10, scoring='accuracy')
# Out:
# Epoch 1/300
# 135/135 [==============================] - 0s 601us/step - loss: 1.8181 - categorical_accuracy: 0.4667
# Epoch 2/300
# 135/135 [==============================] - 0s 122us/step - loss: 1.3699 - categorical_accuracy: 0.6296
# Epoch 3/300
# 135/135 [==============================] - 0s 120us/step - loss: 1.0579 - categorical_accuracy: 0.5926
# Epoch 4/300
# 135/135 [==============================] - 0s 147us/step - loss: 0.9928 - categorical_accuracy: 0.1407
# Epoch 5/300
# 135/135 [==============================] - 0s 192us/step - loss: 0.9518 - categorical_accuracy: 0.2370
# Epoch 6/300
# 135/135 [==============================] - 0s 158us/step - loss: 0.9189 - categorical_accuracy: 0.3852
# Epoch 7/300
# 135/135 [==============================] - 0s 198us/step - loss: 0.8912 - categorical_accuracy: 0.4000
# Epoch 8/300
# 135/135 [==============================] - 0s 167us/step - loss: 0.8638 - categorical_accuracy: 0.3630
# Epoch 9/300
# ...

# %%
print(f'Média: {result.mean()}')
print(f'STD: {result.std()}')
