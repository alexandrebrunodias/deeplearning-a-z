# %%
import tensorflow as tf
from keras.datasets import mnist
from keras.utils import np_utils
from sklearn.model_selection import StratifiedKFold
import pandas as pd
import numpy as np

seed = 42
np.random.seed(seed)
# Out:
# Using TensorFlow backend.

# %%
(X, y), (_,_) = mnist.load_data()

X = X.reshape(X.shape[0], 28, 28, 1)
X = X.astype('float32')/255
# y = np_utils.to_categorical(y, 10)

# %%
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
result = []

# %%
i = 1
for index_train, index_test in kfold.split(X, np.zeros(shape = (y.shape[0], 1))):
    print(f'Epoch: {i}ª')
    i+=1
    
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Conv2D(32, (3,3), input_shape=(28, 28, 1), activation='relu'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
    
    model.add(tf.keras.layers.Conv2D(32, (3,3), activation='relu'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
    
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(units=128, activation='relu'))
    model.add(tf.keras.layers.Dropout(0.2))
    model.add(tf.keras.layers.Dense(units=128, activation='relu'))
    model.add(tf.keras.layers.Dropout(0.2))
    model.add(tf.keras.layers.Dense(units=10, activation='softmax'))
    
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])  
    model.fit(X[index_train], y[index_train], batch_size=128, epochs=5)
    result.append(model.evaluate(X[index_test], y[index_test])[1])
# Out:
# Epoch: 1ª
# Train on 48000 samples
# Epoch 1/5
# 48000/48000 [==============================] - 32s 661us/sample - loss: 0.2369 - accuracy: 0.9282
# Epoch 2/5
# 48000/48000 [==============================] - 30s 625us/sample - loss: 0.0725 - accuracy: 0.9786
# Epoch 3/5
# 48000/48000 [==============================] - 30s 630us/sample - loss: 0.0512 - accuracy: 0.9845
# Epoch 4/5
# 48000/48000 [==============================] - 31s 643us/sample - loss: 0.0389 - accuracy: 0.9884
# Epoch 5/5
# 48000/48000 [==============================] - 29s 608us/sample - loss: 0.0315 - accuracy: 0.9899
# 12000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Epoch: 2ª
# Train on 48000 samples
# Epoch 1/5
# 48000/48000 [==============================] - 31s 656us/sample - loss: 0.2295 - accuracy: 0.9293
# Epoch 2/5
# 48000/48000 [==============================] - 31s 637us/sample - loss: 0.0676 - accuracy: 0.9800
# Epoch 3/5
# 48000/48000 [==============================] - 30s 619us/sample - loss: 0.0487 - accuracy: 0.9855
# Epoch 4/5
# 48000/48000 [==============================] - 30s 626us/sample - loss: 0.0374 - accuracy: 0.9894
# Epoch 5/5
# 48000/48000 [==============================] - 32s 659us/sample - loss: 0.0319 - accuracy: 0.9900
# 12000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Epoch: 3ª
# Train on 48000 samples
# Epoch 1/5
# 48000/48000 [==============================] - 31s 649us/sample - loss: 0.2333 - accuracy: 0.9275
# Epoch 2/5
# 48000/48000 [==============================] - 28s 592us/sample - loss: 0.0666 - accuracy: 0.9798
# Epoch 3/5
# 48000/48000 [==============================] - 28s 589us/sample - loss: 0.0472 - accuracy: 0.9856
# Epoch 4/5
# 48000/48000 [==============================] - 28s 589us/sample - loss: 0.0362 - accuracy: 0.9892
# Epoch 5/5
# 48000/48000 [==============================] - 28s 589us/sample - loss: 0.0305 - accuracy: 0.9904
# 12000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Epoch: 4ª
# Train on 48000 samples
# Epoch 1/5
# 48000/48000 [==============================] - 28s 589us/sample - loss: 0.2349 - accuracy: 0.9280
# Epoch 2/5
# 48000/48000 [==============================] - 28s 588us/sample - loss: 0.0701 - accuracy: 0.9789
# Epoch 3/5
# 48000/48000 [==============================] - 32s 666us/sample - loss: 0.0486 - accuracy: 0.9849
# Epoch 4/5
# 48000/48000 [==============================] - 30s 630us/sample - loss: 0.0347 - accuracy: 0.9893
# Epoch 5/5
# 48000/48000 [==============================] - 30s 633us/sample - loss: 0.0301 - accuracy: 0.9906
# 12000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Epoch: 5ª
# Train on 48000 samples
# Epoch 1/5
# 48000/48000 [==============================] - 30s 616us/sample - loss: 0.2221 - accuracy: 0.9324
# Epoch 2/5
# 48000/48000 [==============================] - 29s 614us/sample - loss: 0.0688 - accuracy: 0.9792
# Epoch 3/5
# 48000/48000 [==============================] - 29s 599us/sample - loss: 0.0483 - accuracy: 0.9854
# Epoch 4/5
# 48000/48000 [==============================] - 31s 654us/sample - loss: 0.0390 - accuracy: 0.9882
# Epoch 5/5
# 48000/48000 [==============================] - 26s 547us/sample - loss: 0.0317 - accuracy: 0.9900
# 12000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
result
# Out:
# [0.9885833, 0.99008334, 0.9855, 0.98791665, 0.9859167]

# %%
print(sum(result) / len(result))
# Out:
# 0.9875999927520752
